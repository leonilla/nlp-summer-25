# %% [markdown]
# <a href="https://colab.research.google.com/github/leonilla/nlp-summer-25/blob/master/FlauschErkennung/bert_multilingual_classification_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install package, import tokenizer
# !pip install -q transformers
from transformers import BertTokenizer

BertTokenizer.from_pretrained('bert-base-multilingual-uncased', do_lower_case=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.72M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# ...

# %%
# Model should receive the CLS token for each instance and map it to a yes/no output (indicating presence or absence of Flausch)

model = SentimentModel()

# Init texts
texts = [
    "hahahahah voll cool . der lehrer hat auswehrsehen das video angeklickt war voll geil",
    "lehrer neven ganz übel ich beebde den unterricht ( facepalm )",
    "cool wie immer . Macht weiter so :)",
    "+ Lu Spindler ran an die Sportklamotten ! 😁",
    "Omg 😍 omg 😍 omg 😍 das video ist einfach so shönn geworden aww deine augen sind so sc Hönn 😍 😍 ich liebe diich und deine videos yoh sehr ❤ love you LuNa 😍 😘"
    ]

result = model.predict_sentiment(texts)

# Print results
print(f"Results:{result}")
print(f"Expected:[positive, negative, positive, negative, positive]")
# Out:
# Results:['positive', 'negative', 'positive', 'negative', 'negative']
# Expected:[positive, negative, positive, negative, positive]
